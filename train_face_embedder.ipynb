# %%
from dataset.tiny_celebrities import train_loader, test_loader
from face_embedder.Model import Model
import pytorch_lightning as pl
# Out:
# Repo card metadata block was not found. Setting CardData to empty.
# Dataset({
#     features: ['image', 'label'],
#     num_rows: 18
# })

# %%
trainer = pl.Trainer(
    max_epochs=100,
)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs

# %%
model = Model(6, embedding_dim=10)
# Out:
# /Users/jakubbednarski/Desktop/Studia/sem2/dlf/venv/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/jakubbednarski/Desktop/Studia/sem2/dlf/venv/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
trainer.fit(model, train_loader, test_loader)
# Out:
#   | Name          | Type        | Params | Mode
# ------------------------------------------------------
# 0 | embedder      | Embedder    | 24.6 M | train
# 1 | loss_function | ArcFaceLoss | 60     | train
# ------------------------------------------------------
# 24.6 M    Trainable params
# 0         Non-trainable params
# 24.6 M    Total params
# 98.249    Total estimated model params size (MB)
# 157       Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /Users/jakubbednarski/Desktop/Studia/sem2/dlf/venv/lib/python3.11/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:424: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# ...

# %%
import matplotlib.pyplot as plt
import einops
from face_embedder.face import align_most_confident_face

# %%
c = iter(test_loader)
example = next(c)
image = example['image']
image = align_most_confident_face(image)
plt.imshow(einops.rearrange(image, 'c h w -> h w c'))
image = einops.rearrange(image, 'c h w -> 1 c h w')

# %%
example = next(iter(train_loader))
image2 = example['image']
image2 = align_most_confident_face(image2)
plt.imshow(einops.rearrange(image2, 'c h w -> h w c'))
image2 = einops.rearrange(image2, 'c h w -> 1 c h w')

# %%
example = next(iter(train_loader))
image3 = example['image']
image3 = align_most_confident_face(image3)
plt.imshow(einops.rearrange(image3, 'c h w -> h w c'))
image3 = einops.rearrange(image3, 'c h w -> 1 c h w')

# %%
boris_embedding = model(image2)
boris2_embedding = model(image3)
not_boris_embedding = model(image)

# %%
print(boris_embedding)
print(boris2_embedding)
print(not_boris_embedding)
# Out:
# tensor([[-0.0115,  0.0043,  0.2664,  0.0051,  0.4521,  0.0141, -0.3273, -0.2730,
#          -0.1884, -0.2574]], grad_fn=<AddmmBackward0>)
# tensor([[-0.0203,  0.0025,  0.2453,  0.0164,  0.4486,  0.0050, -0.3381, -0.2628,
#          -0.1985, -0.2463]], grad_fn=<AddmmBackward0>)
# tensor([[-0.1281,  0.0891,  0.1488, -0.0959, -0.0223,  0.1186,  0.0550,  0.0396,
#           0.0379,  0.0571]], grad_fn=<AddmmBackward0>)

# %%
import torch
cosine_similarity = torch.nn.CosineSimilarity()

# %%
cosine_similarity(boris_embedding, boris2_embedding)
# Out:
# tensor([0.9990], grad_fn=<SumBackward1>)

# %%
cosine_similarity(boris_embedding, not_boris_embedding)
# Out:
# tensor([-0.0856], grad_fn=<SumBackward1>)
